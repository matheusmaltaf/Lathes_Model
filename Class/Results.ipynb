# %%
import numpy as np
import pandas as pd
import pickle

# %%
input_id = 2

PATH = "Classification/Classifiers_result__{}__%i__.pkl".format(input_id)


N = 5

# %%
df = pd.DataFrame()

for i in range(N):
    results_dict = pickle.load(open(PATH %(i),'rb'))

    for gra in results_dict.keys():
        if type(results_dict[gra]) != str:
            n_classifiers = len(results_dict[gra].keys())
            for clf in results_dict[gra].keys():
                aux_dict = results_dict[gra][clf]
                aux_dict['Granularity'] = gra
                aux_dict['Classifier'] = clf
                aux_dict['Iteration'] = i
                aux_dict['Time'] = results_dict[gra][clf]['time']
                df = df.append(aux_dict, ignore_index=True)

# %%
df['Time[min]'] = df['Time'].dt.total_seconds()/(100*60)

# %%
results_df = df.groupby(['Classifier','Granularity']).agg({'Accuracy':['mean','std'],
                                             'Precision':['mean','std'],
                                             'Recall':['mean','std'],
                                             'F1':['mean','std'],
                                             'Time[min]':['mean', 'std']})*100

# %%
results_df.loc['Neural Net']
# Out:
#             Accuracy      Precision      Recall          F1      Time[min]  \
#                 mean  std      mean  std   mean  std   mean  std      mean
# Granularity
# 2.0            100.0  0.0     100.0  0.0  100.0  0.0  100.0  0.0  1.449027
# 3.0            100.0  0.0     100.0  0.0  100.0  0.0  100.0  0.0  1.449027
# 4.0            100.0  0.0     100.0  0.0  100.0  0.0  100.0  0.0  1.449027
#
#
#                   std
# Granularity
# 2.0          0.077168
# 3.0          0.077168
# 4.0          0.077168

# %%
results_df
# Out:
#                                  Accuracy           Precision       \
#                                      mean       std      mean  std
# Classifier        Granularity
# AdaBoost          2.0           99.663866  0.751619     100.0  0.0
#                   3.0           99.663866  0.751619     100.0  0.0
#                   4.0           99.663866  0.751619     100.0  0.0
# Decision Tree     2.0           99.663866  0.751619     100.0  0.0
#                   3.0           99.495798  0.751619     100.0  0.0
#                   4.0           99.495798  0.751619     100.0  0.0
# Gaussian Process  2.0          100.000000  0.000000     100.0  0.0
#                   3.0          100.000000  0.000000     100.0  0.0
#                   4.0          100.000000  0.000000     100.0  0.0
# Linear SVM        2.0          100.000000  0.000000     100.0  0.0
#                   3.0          100.000000  0.000000     100.0  0.0
#                   4.0          100.000000  0.000000     100.0  0.0
# Naive Bayes       2.0           98.987324  0.706077     100.0  0.0
#                   3.0           98.987324  0.706077     100.0  0.0
#                   4.0           98.987324  0.706077     100.0  0.0
# Nearest Neighbors 2.0          100.000000  0.000000     100.0  0.0
#                   3.0          100.000000  0.000000     100.0  0.0
#                   4.0          100.000000  0.000000     100.0  0.0
# Neural Net        2.0          100.000000  0.000000     100.0  0.0
#                   3.0          100.000000  0.000000     100.0  0.0
#                   4.0          100.000000  0.000000     100.0  0.0
# QDA               2.0          100.000000  0.000000     100.0  0.0
#                   3.0          100.000000  0.000000     100.0  0.0
#                   4.0          100.000000  0.000000     100.0  0.0
# RBF SVM           2.0           68.753739  1.478568     100.0  0.0
#                   3.0           68.753739  1.478568     100.0  0.0
#                   4.0           68.753739  1.478568     100.0  0.0
# Random Forest     2.0           99.494374  0.752422     100.0  0.0
#                   3.0           99.494374  0.752422     100.0  0.0
#                   4.0           99.494374  0.752422     100.0  0.0
#
#                                    Recall                    F1            \
#                                      mean       std        mean       std
# Classifier        Granularity
# AdaBoost          2.0           99.166667  1.863390   99.574468  0.951518
#                   3.0           99.166667  1.863390   99.574468  0.951518
#                   4.0           99.166667  1.863390   99.574468  0.951518
# Decision Tree     2.0           99.166667  1.863390   99.574468  0.951518
#                   3.0           98.750000  1.863390   99.363942  0.950279
#                   4.0           98.750000  1.863390   99.363942  0.950279
# Gaussian Process  2.0          100.000000  0.000000  100.000000  0.000000
#                   3.0          100.000000  0.000000  100.000000  0.000000
#                   4.0          100.000000  0.000000  100.000000  0.000000
# Linear SVM        2.0          100.000000  0.000000  100.000000  0.000000
#                   3.0          100.000000  0.000000  100.000000  0.000000
#                   4.0          100.000000  0.000000  100.000000  0.000000
# Naive Bayes       2.0           97.500000  1.743042   98.727884  0.891422
#                   3.0           97.500000  1.743042   98.727884  0.891422
#                   4.0           97.500000  1.743042   98.727884  0.891422
# Nearest Neighbors 2.0          100.000000  0.000000  100.000000  0.000000
#                   3.0          100.000000  0.000000  100.000000  0.000000
#                   4.0          100.000000  0.000000  100.000000  0.000000
# Neural Net        2.0          100.000000  0.000000  100.000000  0.000000
#                   3.0          100.000000  0.000000  100.000000  0.000000
#                   4.0          100.000000  0.000000  100.000000  0.000000
# QDA               2.0          100.000000  0.000000  100.000000  0.000000
#                   3.0          100.000000  0.000000  100.000000  0.000000
#                   4.0          100.000000  0.000000  100.000000  0.000000
# RBF SVM           2.0           22.916667  3.897560   37.159853  5.058885
#                   3.0           22.916667  3.897560   37.159853  5.058885
#                   4.0           22.916667  3.897560   37.159853  5.058885
# Random Forest     2.0           98.750000  1.863390   99.363942  0.950279
#                   3.0           98.750000  1.863390   99.363942  0.950279
#                   4.0           98.750000  1.863390   99.363942  0.950279
#
#                               Time[min]
#                                    mean       std
# Classifier        Granularity
# AdaBoost          2.0          1.449160  0.077164
#                   3.0          1.449149  0.077166
#                   4.0          1.449142  0.077168
# Decision Tree     2.0          1.449023  0.077168
#                   3.0          1.449023  0.077168
#                   4.0          1.449022  0.077168
# Gaussian Process  2.0          1.449090  0.077181
#                   3.0          1.449081  0.077153
#                   4.0          1.449081  0.077165
# Linear SVM        2.0          1.449024  0.077169
#                   3.0          1.449024  0.077168
#                   4.0          1.449024  0.077168
# Naive Bayes       2.0          1.449024  0.077168
#                   3.0          1.449024  0.077168
#                   4.0          1.449024  0.077168
# Nearest Neighbors 2.0          1.449100  0.077169
#                   3.0          1.449097  0.077166
#                   4.0          1.449091  0.077168
# Neural Net        2.0          1.449027  0.077168
#                   3.0          1.449027  0.077168
#                   4.0          1.449027  0.077168
# QDA               2.0          1.449024  0.077168
#                   3.0          1.449024  0.077168
#                   4.0          1.449024  0.077168
# RBF SVM           2.0          1.449050  0.077169
#                   3.0          1.449052  0.077170
#                   4.0          1.449047  0.077169
# Random Forest     2.0          1.449181  0.077166
#                   3.0          1.449173  0.077166
#                   4.0          1.449177  0.077174

# %%
results_df.to_csv('Results/results_{}.csv'.format(input_id))

# %%
results_df.loc[(slice(None), slice(2)), :]
# Out:
#                                  Accuracy           Precision       \
#                                      mean       std      mean  std
# Classifier        Granularity
# AdaBoost          2.0           99.663866  0.751619     100.0  0.0
# Decision Tree     2.0           99.663866  0.751619     100.0  0.0
# Gaussian Process  2.0          100.000000  0.000000     100.0  0.0
# Linear SVM        2.0          100.000000  0.000000     100.0  0.0
# Naive Bayes       2.0           98.987324  0.706077     100.0  0.0
# Nearest Neighbors 2.0          100.000000  0.000000     100.0  0.0
# Neural Net        2.0          100.000000  0.000000     100.0  0.0
# QDA               2.0          100.000000  0.000000     100.0  0.0
# RBF SVM           2.0           68.753739  1.478568     100.0  0.0
# Random Forest     2.0           99.494374  0.752422     100.0  0.0
#
#                                    Recall                    F1            \
#                                      mean       std        mean       std
# Classifier        Granularity
# AdaBoost          2.0           99.166667  1.863390   99.574468  0.951518
# Decision Tree     2.0           99.166667  1.863390   99.574468  0.951518
# Gaussian Process  2.0          100.000000  0.000000  100.000000  0.000000
# Linear SVM        2.0          100.000000  0.000000  100.000000  0.000000
# Naive Bayes       2.0           97.500000  1.743042   98.727884  0.891422
# Nearest Neighbors 2.0          100.000000  0.000000  100.000000  0.000000
# Neural Net        2.0          100.000000  0.000000  100.000000  0.000000
# QDA               2.0          100.000000  0.000000  100.000000  0.000000
# RBF SVM           2.0           22.916667  3.897560   37.159853  5.058885
# Random Forest     2.0           98.750000  1.863390   99.363942  0.950279
#
#                               Time[min]
#                                    mean       std
# Classifier        Granularity
# AdaBoost          2.0          1.449160  0.077164
# Decision Tree     2.0          1.449023  0.077168
# Gaussian Process  2.0          1.449090  0.077181
# Linear SVM        2.0          1.449024  0.077169
# Naive Bayes       2.0          1.449024  0.077168
# Nearest Neighbors 2.0          1.449100  0.077169
# Neural Net        2.0          1.449027  0.077168
# QDA               2.0          1.449024  0.077168
# RBF SVM           2.0          1.449050  0.077169
# Random Forest     2.0          1.449181  0.077166

# %%
(results_df.loc[(slice(None), slice(2)), 'Time[min]']['mean'] - 1)*60
# Out:
# Classifier         Granularity
# AdaBoost           2.0            26.949602
# Decision Tree      2.0            26.941364
# Gaussian Process   2.0            26.945416
# Linear SVM         2.0            26.941469
# Naive Bayes        2.0            26.941434
# Nearest Neighbors  2.0            26.946026
# Neural Net         2.0            26.941618
# QDA                2.0            26.941447
# RBF SVM            2.0            26.943000
# Random Forest      2.0            26.950890
# Name: mean, dtype: float64

# %%
(results_df.loc[(slice(None), slice(2)), 'Time[min]']['std'])*60
# Out:
# Classifier         Granularity
# AdaBoost           2.0            4.629862
# Decision Tree      2.0            4.630085
# Gaussian Process   2.0            4.630851
# Linear SVM         2.0            4.630119
# Naive Bayes        2.0            4.630089
# Nearest Neighbors  2.0            4.630150
# Neural Net         2.0            4.630088
# QDA                2.0            4.630073
# RBF SVM            2.0            4.630147
# Random Forest      2.0            4.629949
# Name: std, dtype: float64
