# %%
import numpy as np
import pandas as pd
import pickle

# %%
input_id = 6

PATH = "Classification/Classifiers_result__{}__%i__.pkl".format(input_id)


N = 5

# %%
df = pd.DataFrame()

for i in range(N):
    results_dict = pickle.load(open(PATH %(i),'rb'))

    for gra in results_dict.keys():
        if type(results_dict[gra]) != str:
            n_classifiers = len(results_dict[gra].keys())
            for clf in results_dict[gra].keys():
                aux_dict = results_dict[gra][clf]
                aux_dict['Granularity'] = gra
                aux_dict['Classifier'] = clf
                aux_dict['Iteration'] = i
                aux_dict['Time'] = results_dict[gra][clf]['time']
                df = df.append(aux_dict, ignore_index=True)

# %%
df['Time[min]'] = df['Time'].dt.total_seconds()/(100*60)

# %%
results_df = df.groupby(['Classifier','Granularity']).agg({'Accuracy':['mean','std'],
                                             'Precision':['mean','std'],
                                             'Recall':['mean','std'],
                                             'F1':['mean','std'],
                                             'Time[min]':['mean', 'std']})*100

# %%
results_df.loc['Neural Net']
# Out:
#                Accuracy            Precision            Recall       \
#                    mean       std       mean        std   mean  std
# Granularity
# 2.0           89.861843  9.382794   82.39656  16.191427  100.0  0.0
# 3.0          100.000000  0.000000  100.00000   0.000000  100.0  0.0
# 4.0          100.000000  0.000000  100.00000   0.000000  100.0  0.0
#
#                      F1           Time[min]
#                    mean       std      mean       std
# Granularity
# 2.0           89.672593  9.523792   1.93417  0.032978
# 3.0          100.000000  0.000000   1.93417  0.032978
# 4.0          100.000000  0.000000   1.93417  0.032978

# %%
results_df
# Out:
#                                  Accuracy             Precision             \
#                                      mean       std        mean        std
# Classifier        Granularity
# AdaBoost          2.0           89.861843  9.382794   82.396560  16.191427
#                   3.0          100.000000  0.000000  100.000000   0.000000
#                   4.0          100.000000  0.000000  100.000000   0.000000
# Decision Tree     2.0           89.524284  8.927201   82.396560  16.191427
#                   3.0           98.307933  1.201008   99.574468   0.951518
#                   4.0           98.646916  1.138582   99.591837   0.912681
# Gaussian Process  2.0           89.861843  9.382794   82.396560  16.191427
#                   3.0          100.000000  0.000000  100.000000   0.000000
#                   4.0          100.000000  0.000000  100.000000   0.000000
# Linear SVM        2.0           89.861843  9.382794   82.396560  16.191427
#                   3.0          100.000000  0.000000  100.000000   0.000000
#                   4.0          100.000000  0.000000  100.000000   0.000000
# Naive Bayes       2.0           89.693776  9.160694   82.396560  16.191427
#                   3.0           99.494374  0.461580  100.000000   0.000000
#                   4.0           99.494374  0.461580  100.000000   0.000000
# Nearest Neighbors 2.0           89.861843  9.382794   82.396560  16.191427
#                   3.0          100.000000  0.000000  100.000000   0.000000
#                   4.0          100.000000  0.000000  100.000000   0.000000
# Neural Net        2.0           89.861843  9.382794   82.396560  16.191427
#                   3.0          100.000000  0.000000  100.000000   0.000000
#                   4.0          100.000000  0.000000  100.000000   0.000000
# QDA               2.0           89.861843  9.382794   82.396560  16.191427
#                   3.0          100.000000  0.000000  100.000000   0.000000
#                   4.0          100.000000  0.000000  100.000000   0.000000
# RBF SVM           2.0           64.695912  8.051148   70.068524  27.403354
#                   3.0           72.295969  2.202087  100.000000   0.000000
#                   4.0           72.295969  2.202087  100.000000   0.000000
# Random Forest     2.0           89.524284  8.927201   82.396560  16.191427
