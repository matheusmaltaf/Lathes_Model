# %%
import pickle
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('Input/Input_0.csv', header=None, index_col=None, names=['id', 'time_id',
                                                                           'Current A', 'Current B', 'Current C',
                                                                           'Voltage A', 'Voltage B', 'Voltage C',
                                                                           'Target'])

# %%
data.head()
# Out:
#      id  time_id  Current A  Current B  Current C  Voltage A  Voltage B  \
# 0  10.0      1.0   2.527771   2.354736   2.528076   3.205261   3.323059
# 1  10.0      2.0   2.673035   2.893372   2.940063   2.469482   2.557678
# 2  10.0      3.0   2.353516   2.375793   2.394714   2.374573   2.446289
# 3  10.0      4.0   2.167053   1.892395   2.399597   3.119202   2.307434
# 4  10.0      5.0   2.450562   2.419739   2.499084   3.129578   3.273621
#
#    Voltage C  Target
# 0   2.733154     0.0
# 1   2.084656     0.0
# 2   2.053223     0.0
# 3   3.140869     0.0
# 4   2.700500     0.0

# %%
plt.figure(figsize=(15,5))
plt.plot(data.values[:3584, 4])
